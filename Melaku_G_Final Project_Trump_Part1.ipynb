# %% [markdown]
# <h1><center>MIS 670 - Final Project</center></h1>

# %% [markdown]
# <h1><center>Post Election Social Media Sentiment Analysis </center></h1>

# %% [markdown]
# ## INTRODUCTON
#
# (refer __Biden_Part1__ notebook)....

# %% [markdown]
# ### OBJECTIVE (BUSINESS QUESTIONS)
#
# (refer __Biden_Part1__ notebook)....

# %% [markdown]
# ### Import Libraries

# %%
# import popular packages
import csv
import pandas as pd
import re
import json

# %% [markdown]
# ## Donald Trump's Tweet

# %%
# Get JSON Data where tweets are stored
with open('/content/realDonaldTrump.json', 'r') as f:
    line = f.readline() # read only the first tweet/line
    tweet = json.loads(line) # load it as Python dictionary
    print((json.dumps(tweet, indent=4)))
# Out:
# {
#     "created_at": "Wed Nov 11 02:38:59 +0000 2020",
#     "id": 1326353700663795718,
#     "id_str": "1326353700663795718",
#     "text": "RT @BlogVermelho: @realDonaldTrump @realDonaldTrump \nLOOOOOZEEERRRR. https://t.co/D3ZT58SlC5",
#     "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#     "truncated": false,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "in_reply_to_screen_name": null,
#     "user": {
#         "id": 1304148360996302855,
#         "id_str": "1304148360996302855",
#         "name": "Franchesca Wiley",
#         "screen_name": "FranchescaWile4",
#         "location": null,
#         "url": null,
#         "description": null,
#         "translator_type": "none",
#         "protected": false,
#         "verified": false,
#         "followers_count": 3,
#         "friends_count": 13,
#         "listed_count": 0,
#         "favourites_count": 73,
#         "statuses_count": 124,
#         "created_at": "Thu Sep 10 20:03:08 +0000 2020",
#         "utc_offset": null,
#         "time_zone": null,
#         "geo_enabled": false,
#         "lang": null,
#         "contributors_enabled": false,
#         "is_translator": false,
#         "profile_background_color": "F5F8FA",
#         "profile_background_image_url": "",
#         "profile_background_image_url_https": "",
#         "profile_background_tile": false,
#         "profile_link_color": "1DA1F2",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "profile_image_url": "http://pbs.twimg.com/profile_images/1304148965219278848/-Zd2W-YT_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/1304148965219278848/-Zd2W-YT_normal.jpg",
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/1304148360996302855/1604886900",
#         "default_profile": true,
#         "default_profile_image": false,
#         "following": null,
#         "follow_request_sent": null,
#         "notifications": null
#     },
#     "geo": null,
#     "coordinates": null,
#     "place": null,
#     "contributors": null,
#     "retweeted_status": {
#         "created_at": "Wed Nov 11 02:37:20 +0000 2020",
#         "id": 1326353287445180416,
#         "id_str": "1326353287445180416",
#         "text": "@realDonaldTrump @realDonaldTrump \nLOOOOOZEEERRRR. https://t.co/D3ZT58SlC5",
#         "display_text_range": [
#             17,
#             50
#         ],
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "truncated": false,
#         "in_reply_to_status_id": 1326353226749386757,
#         "in_reply_to_status_id_str": "1326353226749386757",
#         "in_reply_to_user_id": 25073877,
#         "in_reply_to_user_id_str": "25073877",
#         "in_reply_to_screen_name": "realDonaldTrump",
#         "user": {
#             "id": 23078337,
#             "id_str": "23078337",
#             "name": "\u2014\u2014\u2014crIME\u2014\u2014\u2014",
#             "screen_name": "BlogVermelho",
#             "location": "USA",
#             "url": null,
#             "description": null,
#             "translator_type": "none",
#             "protected": false,
#             "verified": false,
#             "followers_count": 2933,
#             "friends_count": 340,
#             "listed_count": 55,
#             "favourites_count": 8246,
#             "statuses_count": 20844,
#             "created_at": "Fri Mar 06 15:45:18 +0000 2009",
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "profile_background_color": "F5280C",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme9/bg.gif",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme9/bg.gif",
#             "profile_background_tile": true,
#             "profile_link_color": "0099CC",
#             "profile_sidebar_border_color": "FFFFFF",
#             "profile_sidebar_fill_color": "E80932",
#             "profile_text_color": "2B282B",
#             "profile_use_background_image": true,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1324316454041329664/wMNw13PS_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1324316454041329664/wMNw13PS_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/23078337/1578118605",
#             "default_profile": false,
#             "default_profile_image": false,
#             "following": null,
#             "follow_request_sent": null,
#             "notifications": null
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "quote_count": 0,
#         "reply_count": 0,
#         "retweet_count": 1,
#         "favorite_count": 24,
#         "entities": {
#             "hashtags": [],
#             "urls": [],
#             "user_mentions": [
#                 {
#                     "screen_name": "realDonaldTrump",
#                     "name": "Donald J. Trump",
#                     "id": 25073877,
#                     "id_str": "25073877",
#                     "indices": [
#                         0,
#                         16
#                     ]
#                 },
#                 {
#                     "screen_name": "realDonaldTrump",
#                     "name": "Donald J. Trump",
#                     "id": 25073877,
#                     "id_str": "25073877",
#                     "indices": [
#                         17,
#                         33
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "media": [
#                 {
#                     "id": 1326353282730766336,
#                     "id_str": "1326353282730766336",
#                     "indices": [
#                         51,
#                         74
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/EmgnSIfXMAAwX3M.jpg",
#                     "media_url_https": "https://pbs.twimg.com/media/EmgnSIfXMAAwX3M.jpg",
#                     "url": "https://t.co/D3ZT58SlC5",
#                     "display_url": "pic.twitter.com/D3ZT58SlC5",
#                     "expanded_url": "https://twitter.com/BlogVermelho/status/1326353287445180416/photo/1",
#                     "type": "photo",
#                     "sizes": {
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "small": {
#                             "w": 680,
#                             "h": 680,
#                             "resize": "fit"
#                         },
#                         "medium": {
#                             "w": 1200,
#                             "h": 1200,
#                             "resize": "fit"
#                         },
#                         "large": {
#                             "w": 1584,
#                             "h": 1584,
#                             "resize": "fit"
#                         }
#                     }
#                 }
#             ]
#         },
#         "extended_entities": {
#             "media": [
#                 {
#                     "id": 1326353282730766336,
#                     "id_str": "1326353282730766336",
#                     "indices": [
#                         51,
#                         74
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/EmgnSIfXMAAwX3M.jpg",
#                     "media_url_https": "https://pbs.twimg.com/media/EmgnSIfXMAAwX3M.jpg",
#                     "url": "https://t.co/D3ZT58SlC5",
#                     "display_url": "pic.twitter.com/D3ZT58SlC5",
#                     "expanded_url": "https://twitter.com/BlogVermelho/status/1326353287445180416/photo/1",
#                     "type": "photo",
#                     "sizes": {
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "small": {
#                             "w": 680,
#                             "h": 680,
#                             "resize": "fit"
#                         },
#                         "medium": {
#                             "w": 1200,
#                             "h": 1200,
#                             "resize": "fit"
#                         },
#                         "large": {
#                             "w": 1584,
#                             "h": 1584,
#                             "resize": "fit"
#                         }
#                     }
#                 }
#             ]
#         },
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "filter_level": "low",
#         "lang": "en"
#     },
#     "is_quote_status": false,
#     "quote_count": 0,
#     "reply_count": 0,
#     "retweet_count": 0,
#     "favorite_count": 0,
#     "entities": {
#         "hashtags": [],
#         "urls": [],
#         "user_mentions": [
#             {
#                 "screen_name": "BlogVermelho",
#                 "name": "\u2014\u2014\u2014crIME\u2014\u2014\u2014",
#                 "id": 23078337,
#                 "id_str": "23078337",
#                 "indices": [
#                     3,
#                     16
#                 ]
#             },
#             {
#                 "screen_name": "realDonaldTrump",
#                 "name": "Donald J. Trump",
#                 "id": 25073877,
#                 "id_str": "25073877",
#                 "indices": [
#                     18,
#                     34
#                 ]
#             },
#             {
#                 "screen_name": "realDonaldTrump",
#                 "name": "Donald J. Trump",
#                 "id": 25073877,
#                 "id_str": "25073877",
#                 "indices": [
#                     35,
#                     51
#                 ]
#             }
#         ],
#         "symbols": [],
#         "media": [
#             {
#                 "id": 1326353282730766336,
#                 "id_str": "1326353282730766336",
#                 "indices": [
#                     69,
#                     92
#                 ],
#                 "media_url": "http://pbs.twimg.com/media/EmgnSIfXMAAwX3M.jpg",
#                 "media_url_https": "https://pbs.twimg.com/media/EmgnSIfXMAAwX3M.jpg",
#                 "url": "https://t.co/D3ZT58SlC5",
#                 "display_url": "pic.twitter.com/D3ZT58SlC5",
#                 "expanded_url": "https://twitter.com/BlogVermelho/status/1326353287445180416/photo/1",
#                 "type": "photo",
#                 "sizes": {
#                     "thumb": {
#                         "w": 150,
#                         "h": 150,
#                         "resize": "crop"
#                     },
#                     "small": {
#                         "w": 680,
#                         "h": 680,
#                         "resize": "fit"
#                     },
#                     "medium": {
#                         "w": 1200,
#                         "h": 1200,
#                         "resize": "fit"
#                     },
#                     "large": {
#                         "w": 1584,
#                         "h": 1584,
#                         "resize": "fit"
#                     }
#                 },
#                 "source_status_id": 1326353287445180416,
#                 "source_status_id_str": "1326353287445180416",
#                 "source_user_id": 23078337,
#                 "source_user_id_str": "23078337"
#             }
#         ]
#     },
#     "extended_entities": {
#         "media": [
#             {
#                 "id": 1326353282730766336,
#                 "id_str": "1326353282730766336",
#                 "indices": [
#                     69,
#                     92
#                 ],
#                 "media_url": "http://pbs.twimg.com/media/EmgnSIfXMAAwX3M.jpg",
#                 "media_url_https": "https://pbs.twimg.com/media/EmgnSIfXMAAwX3M.jpg",
#                 "url": "https://t.co/D3ZT58SlC5",
#                 "display_url": "pic.twitter.com/D3ZT58SlC5",
#                 "expanded_url": "https://twitter.com/BlogVermelho/status/1326353287445180416/photo/1",
#                 "type": "photo",
#                 "sizes": {
#                     "thumb": {
#                         "w": 150,
#                         "h": 150,
#                         "resize": "crop"
#                     },
#                     "small": {
#                         "w": 680,
#                         "h": 680,
#                         "resize": "fit"
#                     },
#                     "medium": {
#                         "w": 1200,
#                         "h": 1200,
#                         "resize": "fit"
#                     },
#                     "large": {
#                         "w": 1584,
#                         "h": 1584,
#                         "resize": "fit"
#                     }
#                 },
#                 "source_status_id": 1326353287445180416,
#                 "source_status_id_str": "1326353287445180416",
#                 "source_user_id": 23078337,
#                 "source_user_id_str": "23078337"
#             }
#         ]
#     },
#     "favorited": false,
#     "retweeted": false,
#     "possibly_sensitive": false,
#     "filter_level": "low",
#     "lang": "en",
#     "timestamp_ms": "1605062339355"
# }

# %%
# Get entire JSON File and store in a list

# create an empty list to store Trump's tweets in
data = []

# append each line of the data to our tweets list using the json module
for line in open('/content/realDonaldTrump.json'):
    try:
        data.append(json.loads(line))
    except:
        pass

# lets see how many we got
print(len(data))
# Out:
# 237932

# %%
# Display first five tweets only from the data

for i in data[:5]:
    print(i['text'])
# Out:
# RT @BlogVermelho: @realDonaldTrump @realDonaldTrump
# LOOOOOZEEERRRR. https://t.co/D3ZT58SlC5
# @realDonaldTrump I accept you lost
# Joe Biden is a fraud... He knows that as well. One day all things will come to light and darkness will have no more… https://t.co/2tJ5mYIqCJ
# @DonaldJTrumpJr @Trumps_Darlin @realDonaldTrump https://t.co/wxye5fJIFl
# @realDonaldTrump Trump 2020!

# %%
# Using a new name for this data called tweets (a new list)

tweets = []
for T in data:
    if 'text' in T:
        tweets.append(T)
len(tweets)
# Out:
# 235884

# %%
#display ten screen names (twitter user names)
for i in tweets[:10]:
    print(i['user']['screen_name'])
# Out:
# FranchescaWile4
# madhatter3737
# ValmirMSantos
# crazyka33831184
# cyn040058
# pgodless
# Tess77740016
# pennington_jr
# Rosemondpost
# MishkaFilm

# %%
# save screen_names in another list and display the unique number of tweets

screen_names = [T['user']['screen_name'] for T in tweets]
len(screen_names)
# Out:
# 235884

# %%
# Save the different components of the twitter data into CSV.
# This will eas for converting the twitter data into dataframe.
ids = [T['id_str'] for T in tweets]
times = [T['created_at'] for T in tweets]
texts = [T['text'] for T in tweets]
screen_names = [T['user']['screen_name'] for T in tweets]
followers_count = [T['user']['followers_count'] for T in tweets]
friends_count = [T['user']['friends_count'] for T in tweets]
names = [T['user']['name'] for T in tweets]
lats = [(T['geo']['coordinates'][0] if T['geo'] else None) for T in tweets]
lons = [(T['geo']['coordinates'][1] if T['geo'] else None) for T in tweets]
place_names = [(T['place']['full_name'] if T['place'] else None) for T in tweets]
place_types = [(T['place']['place_type'] if T['place'] else None) for T in tweets]

# open an output csv file to write to
out = open('DonaldTrump.csv', 'w', encoding='UTF-8', newline='')

# write the column names
out.write('id,created at,text,screen name,followers_count,friends_count,name,lat,lon,place name,place type\n')

# merge each individual list into a single list 
rows = list(zip(ids, times, texts, screen_names, followers_count, friends_count, names, lats, lons, place_names, place_types))

# use the writer module on our csv file
csv = csv.writer(out)

# use one value from each of our rows list and write it to the csv as a new row
for row in rows:
    values = [value for value in row]
    #values = [(value.encode('utf8') if hasattr(value, 'encode') else value) for value in row]
    csv.writerow(values)

#close our csv file
out.close()

# %%
# read your CSV data as dataframe
import pandas as pd
df = pd.read_csv('/content/DonaldTrump.csv')
df.head(2)
# Out:
#                     id                      created at  ... place name place type
# 0  1326353700663795718  Wed Nov 11 02:38:59 +0000 2020  ...        NaN        NaN
# 1  1326353700848345089  Wed Nov 11 02:38:59 +0000 2020  ...        NaN        NaN
#
# [2 rows x 11 columns]

# %% [markdown]
# ### Descriptive Analytics

# %% [markdown]
# #### Tweets per user

# %%
# Import counter
from collections import Counter

usercount = Counter(screen_names)
print(usercount)
# Out:
# Counter({'sayfmunir': 271, 'mylrhg1957': 195, 'DanLia1': 130, 'woody33095': 112, 'DJTMentionsBot': 90, 'Bella_40': 88, 'CoxTake': 83, 'pghdrew': 70, 'Chickad68372567': 69, 'GaryRupert15': 66, 'cldeloache': 64, 'MRScott59799542': 64, 'Cleopatragrmtns': 61, 'airedale1951': 61, 'LizKiz2': 59, 'Lee77_1': 59, 'deplorable_it': 57, 'Jpjbl61': 56, 'JOJOFREEDOMK': 56, 'ContrerasTams': 56, 'BartlettUSA2016': 56, 'toml618': 54, 'IAmSergioRoman': 54, 'macdonald_julie': 52, 'MAnayam001': 52, 'Itshmine': 47, 'lulopolar': 46, 'FreddyAHayek': 46, 'AmyMaso88550544': 45, 'yojudenz': 45, 'azeneth_rose': 45, 'MarsRising3': 44, 'lvactionimages': 44, 'jani1881': 43, 'kathlee17255986': 43, 'reneeconner71': 43, 'MiMi___KAA': 42, 'scarlettwidcws': 42, 'carla_biscardi': 41, 'NQyqmWIMOw0jwy4': 41, 'chainik92648': 41, 'tidewatertarot': 41, 'Igetsublime': 41, 'kinimay4': 40, 'Lovefor14520823': 40, 'FletchJ9': 40, 'MilesQBlack1': 39, 'PatrickNova6': 39, 'Daddycasey21': 39, 'braincasale': 39, 'LeoDube': 39, 'CactusFlower_1': 39, 'AnaPorras5': 39, 'AntonioPires61': 38, 'Prophetessdeb7': 38, 'annabel73079078': 37, 'FunTomTweets': 37, 'TJINVA1776': 37, 'GizelleIntense': 37, 'TheSouthPa': 36, 'RickAnt85716711': 35, 'MyGrandpasays3': 35, 'teelorr1954': 34, 'CherieRoberts7': 34, 'Gustoe16': 34, 'OagonyO': 34, 'richatripathi': 34, 'GoldStuart': 34, 'MiddleMolly': 34, 'Porican_01': 34, 'evaedt2020': 33, 'randomnewb1': 33, 'Chris09704800': 33, 'ZacharyIvanPor1': 33, 'Elementumh2o': 33, 'CodyIsAGoodBoy': 32, 'smith_kosta': 32, 'RobertsMobile': 32, 'DavidDickelman': 32, 'denny77910621': 32, 'ahluv2': 31, '13speedOD': 31, 'Candice17822288': 31, 'trumpvember': 31, 'Kmcmoran': 29, 'NickyNoxville': 29, 'Christo02403731': 29, 'JTPTafoya': 29, 'Julie46185729': 29, 'alo_okechukwu': 29, 'BL4USA': 29, 'MrDetilly': 28, 'PollyRomie': 28, 'Tooltimetim5': 28, 'mustangsmedic': 28, 'chrisstuffer': 28, 'GrayGho37296101': 28, 'sweetamyrenee': 28, 'thebling_vote': 28, 'Glassaholic51': 28, 'jh_gibson': 28, 'stephphilip8': 28, 'way4sense': 28, 'icollect22003': 27, 'DovahGol': 27, 'SherryNicopoli2': 27, 'Katheri66169988': 27, 'marleneasmall': 27, 'Jabs46': 27, 'GrapeGrandpa': 27, '_sayazed': 27, 'blaze0497': 27, 'Carver926': 26, 'sjohnson11776': 26, 'StormKayKeeton': 26, 'Sam4Biden': 26, 'fujacky2': 26, 'BrettT18349489': 26, 'HRP_Kanagawa': 26, 'KingOfHitlum': 26, 'Cryptodict1': 26, 'cor_kun': 26, 'dougallday': 26, 'ProudQchick': 25, 'PattyJHudson1': 25, 'LiveBville': 25, 'consmover': 25, 'republican2020x': 25, 'reel_coop': 25, 'jim_shier': 25, 'MrFly187': 25, 'WallDesu': 25, 'BeeNLiveToRide': 25, 'StripedTomato3': 25, 'Prophetyi': 25, 'Rsmall01779737': 25, 'StephanTokarski': 25, 'geoevansiii': 25, 'GoldnemovesGold': 25, 'La0s6pJWQhvKNsQ': 25, 'MImproxyble': 24, 'TrumpForMe2': 24, 'FuroridaNoMaya': 24, 'nancy82414044': 24, 'FreedomChild3': 24, 'Phall1990': 24, 'twittyteppy1978': 24, 'lydiade08505743': 24, 'cj_cj_cj_cj_cj_': 24, 'ingridkirschba3': 23, 'Dburkjr68x': 23, 'RoseDC11': 23, 'ANGELVIXEN213': 23, 'colletteryan56': 23, 'TiedrichS': 23, 'JoeK3Fan': 23, 'mick09865214': 23, 'JEFFGORDON5': 23, 'ElizAKByrd': 23, 'paulferrell1': 23, 'Trace33917745': 23, 'Christianlord12': 23, 'littledrgn13': 23, 'truth_messege': 23, 'hasudi': 23, 'bruceboucek': 23, 'TopTierBall': 23, 'gbroh10': 23, 'IvyTwoPointOh': 23, 'Brucefletcher62': 23, 'mamabergy': 23, 'ClaraMa15': 23, '58Kate': 23, 'aakashsultaan': 23, 'DonnaMadras': 23, 'SirElkMN': 22, 'dianeski': 22, 'Purecharity1': 22, 'JORGE_C_NY': 22, 'RobertP29345993': 22, 'francinest56': 22, 'Rob_AirOne': 22, '2ndGenPat': 22, 'lisamcat': 22, 'jotay682016': 22, 'CHENYI63173840': 22, 'Mariahpsalms119': 22, 'WhiteHatStorm': 22, 'justjo2': 22, 'lyne_ian': 22, 'TaylorMusic8': 22, 'lilyforest51': 22, 'Marlo_Rees': 22, 'skigirl1128': 22, 'bwolpecpa': 22, 'BenjaminS170': 22, 'CindyCinnis': 22, 'Bobbetty12': 21, 'spj121': 21, 'dvillella': 21, 'Ocala200': 21, 'SuicideSeattle': 21, 'Amanda_Walker78': 21, 'ThomasEBrown3': 21, 'jicsbr': 21, 'FalseFlagJoe1': 21, 'auntied ...

# %% [markdown]
# #### How many unique users in Joe Biden's tweets

# %%
#how many unique users in the data?
len(usercount)
# Out:
# 119737

# %% [markdown]
# #### How many tweets per user

# %%
#  how many tweets per user?
print(len(tweets))
print(len(usercount))
round(float(len(tweets)/len(usercount)),3)
# Out:
# 235884
# 119737
# 1.97

# %% [markdown]
# #### Most Active users

# %%
#screen names

screenames = Counter(screen_names)

# ten most active tweeters
screenames.most_common(10)
# Out:
# [('sayfmunir', 271),
#  ('mylrhg1957', 195),
#  ('DanLia1', 130),
#  ('woody33095', 112),
#  ('DJTMentionsBot', 90),
#  ('Bella_40', 88),
#  ('CoxTake', 83),
#  ('pghdrew', 70),
#  ('Chickad68372567', 69),
#  ('GaryRupert15', 66)]

# %% [markdown]
# #### Original tweets vs Retweets

# %%
#remove retweets so you can extract all original tweets and save them

originaltweets = []
originaltweets = [texts['text'] for texts in tweets if 'RT @' not in texts['text'] and 'rt @' not in texts['text'] ]

len(originaltweets)
# Out:
# 130942

# %%
# get retweets only

#remove original tweets

retweets = []
retweets = [texts['text'] for texts in tweets if 'RT @' in texts['text'] or 'rt @' in texts['text'] ]

len(retweets)
# Out:
# 104942

# %% [markdown]
# #### Geographic locations

# %%
# Are users Geo Enabled? (reviewing first 20)
for i in tweets[:20]:
    print(i['user']['geo_enabled'], i['user']['location'])
    
# Create a list of the geo enabled users.
geo=[]
for i in tweets:
    if (str(i['user']['geo_enabled']) == 'True'):
         geo.append(i)
            
for i in geo[:5]:
    print(i['user']['geo_enabled'], i['user']['location'], i['coordinates'])

# Redo the list of so only the geo enabled users that have revealed locations are collected.
geo=[]
for i in tweets:
    if (str(i['user']['geo_enabled']) == 'True' and str(i['user']['location']) != 'None'):
         geo.append(i)
            
for i in geo[:5]:
    print(i['user']['geo_enabled'], i['user']['location'], i['coordinates'])
    
len(geo)

# Redo the list of so only the geo enabled users that have revealed locations are collected with coordinates.
geo=[]
for i in tweets:
    if (str(i['user']['geo_enabled']) == 'True' and str(i['user']['location']) != 'None' and str(i['coordinates']) != 'None'):
         geo.append(i)
            
for i in geo[:5]:
    print(i['user']['geo_enabled'], i['user']['location'], i['coordinates'])
    
len(geo)

# Redo the list only if there were no coordinates revealed
geo=[]
for i in tweets:
        if (str(i['user']['geo_enabled']) == 'True' and str(i['user']['location']) != 'None'):
             geo.append(i) 
                
for i in geo[:5]:
    print(i['user']['geo_enabled'], i['user']['location'])
    
len(geo)

# Put locations into a list
location = [texts['user']['location'] for texts in geo]
len(location)

# Get a counter to calculate the most common locations and display 10
from collections import Counter
c = Counter(location)
c.most_common(10)

#Change it to dataframe
activelocations = c.most_common(10)
activelocations_df = pd.DataFrame(activelocations)
activelocations_df
# Out:
# False None
# True Rising Sun, MD
# True Deerfield Beach, Florida
# False This earthly realm for a time.
# False Maine, USA
# False None
# False Miami, FL
# False None
# True New Orleans, LA
# False Bay Area, California
# False Los Angeles, CA
# False None
# False None
# False Atlanta, GA
# False None
# False None
# False None
# True None
# False None
# False None
# True Rising Sun, MD None
# True Deerfield Beach, Florida None
# True New Orleans, LA None
# True None None
# True None None
# True Rising Sun, MD None
# True Deerfield Beach, Florida None
# True New Orleans, LA None
# True South Side  None
# True Bear, DE None
# True USA {'type': 'Point', 'coordinates': [-82.89785666, 34.55855856]}
# True Rising Sun, MD
# True Deerfield Beach, Florida
# True New Orleans, LA
# True South Side
# True Bear, DE
#                    0     1
# 0      United States  2073
# 1                USA   867
# 2         Texas, USA   646
# 3    California, USA   617
# 4       Florida, USA   481
# 5    Los Angeles, CA   382
# 6  Pennsylvania, USA   256
# 7       New York, NY   251
# 8        Chicago, IL   242
# 9      New York, USA   232

# %% [markdown]
# #### Most visible users

# %%
# First extract all user names from tweets Display 20 (mentions )

import re

# Change to a single column
for tweet in texts[:20]:
    a = re.findall(r"(?<=@)\w+", tweet)
        
        
# Create a new list of all mentioned users
visible_users = []

for tweet in texts:
    a = re.findall(r"@([A-Za-z0-9_]+)", tweet)
    for i in a:
        visible_users.append(['@'+i][0])
        

# Find the 10 most visible users in this dataset with a counter

c = Counter(visible_users)
c.most_common(10)
# Out:
# [('@realDonaldTrump', 188864),
#  ('@POTUS', 10497),
#  ('@DanPatrick', 8246),
#  ('@GOP', 8199),
#  ('@LouDobbs', 6555),
#  ('@FoxNews', 4928),
#  ('@TomFitton', 4822),
#  ('@seanhannity', 4760),
#  ('@SidneyPowell1', 4707),
#  ('@Li', 4562)]

# %% [markdown]
# #### Hashtags

# %%
#Extract and display all hashtags from first 30 tweets of Mercedes Benz

hashtags = []

for tweet in texts[:30]:
    a = re.findall(r"(?<=#)\w+", tweet)
    
    
#  list one hashtag in a row and save 

hashtags = []

for tweet in texts:
    a = re.findall(r"(?<=#)\w+", tweet)
    for i in a:
        hashtags.append(['#'+i][0])
        
        
#Print 15 hashtags
for i in hashtags[:15]:
    print(i)
    
#Most common Hashtags (10)
c = Counter(hashtags)
c.most_common(10)
# Out:
# #ByeByeTrump
# #stolenelection
# #BREAKING
# #FakeNews
# #Jackweeds
# #WeWontStop
# #TrumpConcede
# #25thAmendmentNow
# #Evidence
# #fraud
# #Pennsylvania
# #Elect
# #Whoopi
# #TrumpForever
# #Maidengate
# [('#ChinaJoeBiden', 1619),
#  ('#China', 1607),
#  ('#ChinaJoe', 1605),
#  ('#1', 1175),
#  ('#Pennsylvania', 1050),
#  ('#Evidence', 961),
#  ('#MAGA', 781),
#  ('#fraud', 709),
#  ('#Elect', 694),
#  ('#HappyBirthdayMarines', 588)]

# %% [markdown]
# #### URLs

# %%
# Extract and display urls from the first 10 tweets 
# Notice the way the URLs are formed (e.g. Twitter URL and Actual one)
for i in tweets[:10]:
    print(i['entities']['urls'])
    
for T in tweets[:15]:
    for i in T['entities']['urls']:
        print(i['url'])
# Out:
# []
# []
# [{'url': 'https://t.co/2tJ5mYIqCJ', 'expanded_url': 'https://twitter.com/i/web/status/1326353700579840002', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]
# []
# []
# []
# []
# []
# [{'url': 'https://t.co/WbaIHgBPtd', 'expanded_url': 'https://twitter.com/i/web/status/1326353700961574912', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]
# []
# https://t.co/2tJ5mYIqCJ
# https://t.co/WbaIHgBPtd
# https://t.co/AYbe2Kc2GR

# %% [markdown]
# ### Text Pre-processing

# %% [markdown]
# Now let's start cleaning the data for __sentiment analysis__.

# %%
# First let's change the column heading from 'text' to tweet

df.rename(columns={'text':'tweet'}, inplace=True)
df.head(2)
# Out:
#                     id                      created at  ... place name place type
# 0  1326353700663795718  Wed Nov 11 02:38:59 +0000 2020  ...        NaN        NaN
# 1  1326353700848345089  Wed Nov 11 02:38:59 +0000 2020  ...        NaN        NaN
#
# [2 rows x 11 columns]

# %% [markdown]
# __Change the content of the tweet to all small letter__.

# %%
df['tweet'] = df['tweet'].str.lower()
df.head(2)
# Out:
#                     id                      created at  ... place name place type
# 0  1326353700663795718  Wed Nov 11 02:38:59 +0000 2020  ...        NaN        NaN
# 1  1326353700848345089  Wed Nov 11 02:38:59 +0000 2020  ...        NaN        NaN
#
# [2 rows x 11 columns]

# %% [markdown]
# __Number of characters in each tweet__.

# %%
# Create a column for charcounts
df['charcounts']=df['tweet'].str.len()
df.head(2)
# Out:
#                     id                      created at  ... place type charcounts
# 0  1326353700663795718  Wed Nov 11 02:38:59 +0000 2020  ...        NaN         92
# 1  1326353700848345089  Wed Nov 11 02:38:59 +0000 2020  ...        NaN         34
#
# [2 rows x 12 columns]

# %% [markdown]
# Find out the number of words in each tweet and create a column __"wordcount"__

# %%
df['wordcount'] = df['tweet'].str.split().str.len()
df.head(2)
# Out:
#                     id                      created at  ... charcounts wordcount
# 0  1326353700663795718  Wed Nov 11 02:38:59 +0000 2020  ...         92         6
# 1  1326353700848345089  Wed Nov 11 02:38:59 +0000 2020  ...         34         5
#
# [2 rows x 13 columns]

# %% [markdown]
# Find the average word length and create a column __"avgwordlen"__

# %%
df['avgwordlen']=df['charcounts'] / df['wordcount']
df.head(2)
# Out:
#                     id                      created at  ... wordcount avgwordlen
# 0  1326353700663795718  Wed Nov 11 02:38:59 +0000 2020  ...         6  15.333333
# 1  1326353700848345089  Wed Nov 11 02:38:59 +0000 2020  ...         5   6.800000
#
# [2 rows x 14 columns]

# %% [markdown]
# __Overall average word length__

# %%
df['avgwordlen'].sum() / len(df)
# Out:
# 8.634187055930475

# %% [markdown]
# Find hashtags and creat a column __"hash"__

# %%
df['hash'] = df.tweet.str.findall("(?<=#)\w+")
df.head(2)
# Out:
#                     id                      created at  ... avgwordlen hash
# 0  1326353700663795718  Wed Nov 11 02:38:59 +0000 2020  ...  15.333333   []
# 1  1326353700848345089  Wed Nov 11 02:38:59 +0000 2020  ...   6.800000   []
#
# [2 rows x 15 columns]

# %% [markdown]
# Find the __average number of hashtags per tweet__ and display it below

# %%
df['AvgHashtag']=df['hash'].str.len()
df.head(2)
# Out:
#                     id                      created at  ... hash AvgHashtag
# 0  1326353700663795718  Wed Nov 11 02:38:59 +0000 2020  ...   []          0
# 1  1326353700848345089  Wed Nov 11 02:38:59 +0000 2020  ...   []          0
#
# [2 rows x 16 columns]

# %% [markdown]
# Find Twitter mentions and create a column __"mentions"__

# %%
df['mentions']=df.tweet.str.findall("(?<=@)\w+")
df.head(2)
# Out:
#                     id  ...                                          mentions
# 0  1326353700663795718  ...  [blogvermelho, realdonaldtrump, realdonaldtrump]
# 1  1326353700848345089  ...                                 [realdonaldtrump]
#
# [2 rows x 17 columns]

# %% [markdown]
# ## Text Cleaning

# %% [markdown]
# __Remove numbers__

# %%
# let's change our data frame into df.cleaned

df['cleaned'] = df['tweet']

# replace the numbers
df.cleaned.str.replace('\d+', '')
df['cleaned'] = df.cleaned.str.replace('\d+', '')

# Display
df.cleaned.head()
# Out:
# 0    rt @blogvermelho: @realdonaldtrump @realdonald...
# 1                   @realdonaldtrump i accept you lost
# 2    joe biden is a fraud... he knows that as well....
# 3    @donaldjtrumpjr @trumps_darlin @realdonaldtrum...
# 4                             @realdonaldtrump trump !
# Name: cleaned, dtype: object

# %% [markdown]
# Remove __URLs__ and the update the column

# %%
#remove http and www. URLs
df.cleaned.str.replace('http\S+|www.\S+', '')
df['cleaned'] = df.cleaned.str.replace('http\S+|www.\S+', '')

# Display
df.cleaned.head()
# Out:
# 0    rt @blogvermelho: @realdonaldtrump @realdonald...
# 1                   @realdonaldtrump i accept you lost
# 2    joe biden is a fraud... he knows that as well....
# 3     @donaldjtrumpjr @trumps_darlin @realdonaldtrump
# 4                             @realdonaldtrump trump !
# Name: cleaned, dtype: object

# %% [markdown]
# Remove __non-alphabetic words & characters__ and update the column

# %%
#remove non-alphabetic words
df.cleaned.str.replace('[^a-zA-Z]+', ' ')
df['cleaned'] = df.cleaned.str.replace('[^a-zA-Z]+', ' ')

# Display
df.cleaned.head()
# Out:
# 0    rt blogvermelho realdonaldtrump realdonaldtrum...
# 1                    realdonaldtrump i accept you lost
# 2    joe biden is a fraud he knows that as well one...
# 3        donaldjtrumpjr trumps darlin realdonaldtrump
# 4                               realdonaldtrump trump
# Name: cleaned, dtype: object

# %% [markdown]
# Remove __short words__ (< 3) and update the column

# %%
# remove short words

df.cleaned.str.findall('\w{3,}').str.join(' ')
df['cleaned'] = df.cleaned.str.findall('\w{3,}').str.join(' ')

# Display
df.cleaned.head()
# Out:
# 0    blogvermelho realdonaldtrump realdonaldtrump l...
# 1                      realdonaldtrump accept you lost
# 2    joe biden fraud knows that well one day all th...
# 3         donaldjtrumpjr trumps darlin realdonaldtrump
# 4                                realdonaldtrump trump
# Name: cleaned, dtype: object

# %% [markdown]
# ### Store the __df.cleaned__ into csv file to further process it (due to RAM issues)

# %%
df.cleaned.to_csv('/content/Cleaned_Trump_Part1.csv')

# %%
df.to_csv('/content/Trump_Part1.csv')

# %% [markdown]
# __Part two__ will continue........
